# %%
import plotly.express as px

# %%
import pandas as pd

# %%
df=pd.read_csv("newfile.csv")

# %%
df
# Out:
#           Player  Duration  Matches  innings  NO  Runs  High_score    Ave  \
# 0    DG Bradman         20       52       80  10  6996         334  99.94
# 1   PHKD Mendis          3       12       21   2  1184         182  62.31
# 2      AC Voges          1       20       31   7  1485         269  61.87
# 3    RG Pollock          7       23       41   4  2256         274  60.97
# 4    GA Headley         24       22       40   4  2190         270  60.83
# ..           ...       ...      ...      ...  ..   ...         ...    ...
# 57   KD Walters         16       74      125  14  5357         250  48.26
# 58     GC Smith         12      117      205  13  9265         277  48.25
# 59  WH Ponsford         10       29       48   4  2122         266  48.22
# 60    SJ McCabe          8       39       62   5  2748         232  48.21
# 61   DR Jardine          6       22       33   6  1296         127  48.00
#
#     Balls_faced  Strike_rate  100  50   0    4s  6s Country  start_year  \
# ...

# %%
pdata=df[df["Player"]=="DG Bradman"]

# %%
pdata["Player"]
# Out:
# Series([], Name: Player, dtype: object)

# %%
df2=pdata[["Runs","Matches","Innings","6s","4s","100s","50","Ave","High_score"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df2=pdata[["Runs","Matches","Innings","6s","4s","100s","50","Ave","High_score"]]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
# ...

# %%
df2=df2.T #Transpose
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df2=df2.T #Transpose
#
# NameError: name 'df2' is not defined

# %%
df2=df2.rename(columns={0:"Values"," ":"new"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df2=df2.rename(columns={0:"Values"," ":"new"})
#
# NameError: name 'df2' is not defined

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df2=df2.T.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df2=df2.T.reset_index()
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ##

# %%
df2=
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined
